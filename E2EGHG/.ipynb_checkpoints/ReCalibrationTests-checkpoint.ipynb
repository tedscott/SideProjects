# %% [markdown]
# # Test sliding window of size N
# - does the distribution of the next window of N (i - 99 to i + 1) ever differ from the window of the previous N
# - do the subsequent 10 spans ever fall outside the CIs of median E for the prior N spans

# %% [markdown]
# # import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

import statsmodels.api as sm

from scipy import stats
from scipy.stats import ks_2samp


sns.set_theme(style="whitegrid")

fs=24

# %% [markdown]
# ## Import data

# %%
df_spans_500 = pd.read_csv("../../../Data/E2EGHG/span_500.csv")

# %%
df_spans_500
# Out:
#                                trace.id           span.id  measurements.count  \
# 0      222f87835be6d5fd5163c0efc6ee7ca7  0fba401994f44764                   2
# 1      76bad4ef4b99578975cc03a38983099f  988e64c0db11f61f                   2
# 2      b3a407073d2cac3c0b1f302c4eb356f2  f6200cba4a3fe9c7                   2
# 3      2f382c7721a471041538370db4d53e15  eb258b6dab05d197                   2
# 4      563dd2e8338e1860ff89b4e8af960f83  e71daf18301cd67e                   2
# ...                                 ...               ...                 ...
# 18995  0b3836f2d83aaf3db16762e46fa5c9b0  e3744c1b29b5645b                   8
# 18996  961e134e5e759d6c48e183547628f764  6149e0ae385c4296                   8
# 18997  c3f17c9ef9b4e78d946e04460b00ff79  e8cd3649e3f9421e                   8
# 18998  cdef1565e8c225e2c2a6d65710ff0cd8  3fd4bd202eff1ccf                   8
# 18999  ce2cd3047f128d8b2f54882f98b0caea  69b50186893a36fa                   8
#
# ...

# %%
df_spans_500.columns
# Out:
# Index(['trace.id', 'span.id', 'measurements.count', 'start_time_us',
#        'energy.joules', 'start.energy.joules', 'end.energy.joules',
#        'epler.duration.ms', 'kepler.energy.joules', 'exper_name', 'cpu_ms',
#        'active_interval_ms'],
#       dtype='object')

# %% [markdown]
# ## replace . with _ in column names

# %%
# replace . with _ in column names
df_spans_500.columns = df_spans_500.columns.str.replace('.', '_')
df_spans_500.columns
# Out:
# Index(['trace_id', 'span_id', 'measurements_count', 'start_time_us',
#        'energy_joules', 'start_energy_joules', 'end_energy_joules',
#        'epler_duration_ms', 'kepler_energy_joules', 'exper_name', 'cpu_ms',
#        'active_interval_ms'],
#       dtype='object')

# %%
# create reduced dataset for modeling
df = df_spans_500.drop([ 'trace_id', 'measurements_count', 'start_time_us','start_energy_joules', 'end_energy_joules',
       'epler_duration_ms', 'kepler_energy_joules', 'exper_name'], axis=1)
df.head(10)
# Out:
#             span_id  energy_joules  cpu_ms  active_interval_ms
# 0  0fba401994f44764       0.354891     100                 100
# 1  988e64c0db11f61f       0.285905     100                 100
# 2  f6200cba4a3fe9c7       0.330809     100                 100
# 3  eb258b6dab05d197       0.329298     100                 100
# 4  e71daf18301cd67e       0.392451     100                 100
# 5  8f52ba0a2159e910       0.507373     100                 100
# 6  f352926e0a780dfb       0.365779     100                 100
# 7  8caa5dca490e4acd       0.397780     100                 100
# 8  989c997ac0848a8c       0.487562     100                 100
# 9  70112eb89928f694       0.320725     100                 100

# %% [markdown]
# #### filter out rows with too short active_interval_ms (< 25.0 ms are removed)

# %%
# df = df.query('active_interval_ms >= 25.0')
# df

# %% [markdown]
# ### Get Median E for each cpu_ms

# %%
df_median_e_cpu = df[['energy_joules','cpu_ms']].copy()
df_median_e_cpu = df_median_e_cpu.groupby(['cpu_ms'], as_index=False).median()
df_median_e_cpu
# Out:
#    cpu_ms  energy_joules
# 0      50       0.161429
# 1     100       0.358166
# 2     150       0.556203
# 3     200       0.760293
# 4     250       0.965244
# 5     500       1.984828
# 6    1000       4.073576
# 7    2000       8.481546

# %% [markdown]
# ### add column with median energy for that cpu_ms to each trace_id

# %%
cpu_ms_vals = np.unique(df['cpu_ms'])
for i in cpu_ms_vals:
    df.loc[df['cpu_ms'] == i, 'median_energy_cpu_ms'] = df_median_e_cpu[df_median_e_cpu['cpu_ms'] == i].energy_joules.values[0]

df.head(10)
# Out:
#             span_id  energy_joules  cpu_ms  active_interval_ms  \
# 0  0fba401994f44764       0.354891     100                 100
# 1  988e64c0db11f61f       0.285905     100                 100
# 2  f6200cba4a3fe9c7       0.330809     100                 100
# 3  eb258b6dab05d197       0.329298     100                 100
# 4  e71daf18301cd67e       0.392451     100                 100
# 5  8f52ba0a2159e910       0.507373     100                 100
# 6  f352926e0a780dfb       0.365779     100                 100
# 7  8caa5dca490e4acd       0.397780     100                 100
# 8  989c997ac0848a8c       0.487562     100                 100
# 9  70112eb89928f694       0.320725     100                 100
#
#    median_energy_cpu_ms
# 0              0.358166
# 1              0.358166
# 2              0.358166
# 3              0.358166
# 4              0.358166
# 5              0.358166
# 6              0.358166
# 7              0.358166
# 8              0.358166
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=df, x='cpu_ms', y='energy_joules')#, col='cpu_ms', col_wrap=4, palette='tab10', markers='o', ci=95)
plt.xlabel("span length (ms)", fontsize=fs)
plt.ylabel(r'Energy', fontsize=fs)
# Out:
# Text(0, 0.5, 'Energy')

# %% [markdown]
# ### From the "Taming Performance Variability" paper: "compute $\lfloor{\frac{n - z \sqrt{n}}{ 2}}\rfloor$ and $\lceil{1+\frac{n+z \sqrt{n}  }{2} }\rceil$,where n is the number of elements in X, and z is the standard score (or z-score). z depends only on the desired confidence level, and is 1.96 for the commonly-used level of $\alpha = 95\\\%$. These two numbers are then used as indexes into the sorted X: the values at those locations are the top and the bottom bounds of the CI. Note that one of these numbers will be larger than the median (at index n/2) and the other will be smaller, and they will not necessarily be symmetric around the median. These bounds tend to get tighter—to approach the sample mean—with more repetitions. Typically, we are concerned with the relative difference r% between the CI bounds and the mean."

# %%
# df['gender'] = df['gender'].apply(lambda x: 0 if x == 'female' else x)

#df_filtered_1000_fixed['sampling_ratio'] = df_filtered_1000_fixed['sampling_ratio'].apply(lambda x: 4.000000 if ((x > 4) & (x < 5)) else x)

# %% [markdown]
# #### Build confidence intervals on median Energy - note we are using all data for a span (all measurement frequencies)

# %%
# copy data for experimenting
df_test = df.copy()

# %%
span_lengths = np.unique(df_test.cpu_ms)
span_lengths
# Out:
# array([  50,  100,  150,  200,  250,  500, 1000, 2000])

# %%
# set params for conf intervals calculation
# here using the Z-score for 95% confidence

z = 1.96


temp_df = pd.DataFrame(columns=['n','cpu_ms','median_energy','e_upper_ci','e_lower_ci'])

for span_ms in span_lengths:
    the_n = df_test.query('(cpu_ms == @span_ms)').shape[0]
    lower_ci_idx = int(np.floor((the_n - z*np.sqrt(the_n))/2))
    upper_ci_idx = int(np.ceil(1 + ((the_n + z*np.sqrt(the_n))/2)))
    acc_eng = df_test.query('(cpu_ms == @span_ms)')['energy_joules']
    acc_eng_sorted = np.sort(acc_eng)
    acc_eng_upper_ci = acc_eng_sorted[upper_ci_idx]
    acc_eng_lower_ci = acc_eng_sorted[lower_ci_idx]
    temp_df.loc[len(temp_df.index)] = [the_n, span_ms, acc_eng.median(), acc_eng_upper_ci, acc_eng_lower_ci]
        #print(the_n,span_ms,ratio,acc_eng_upper_ci,acc_eng_lower_ci)

temp_df
# Out:
#         n  cpu_ms  median_energy  e_upper_ci  e_lower_ci
# 0  1000.0    50.0       0.161429    0.162452    0.160210
# 1  1500.0   100.0       0.358166    0.360424    0.355138
# 2  1500.0   150.0       0.556203    0.559315    0.553055
# 3  2000.0   200.0       0.760293    0.764776    0.756992
# 4  2500.0   250.0       0.965244    0.970834    0.960640
# 5  3000.0   500.0       1.984828    1.990903    1.979827
# 6  3500.0  1000.0       4.073576    4.085691    4.060735
# 7  4000.0  2000.0       8.481546    8.511917    8.459635

# %% [markdown]
# ## Plot Median E with CIs

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=temp_df, x='cpu_ms', y='median_energy')
plt.errorbar(temp_df['cpu_ms'], temp_df['median_energy'], yerr=[temp_df['e_lower_ci'],temp_df['e_upper_ci'] ], fmt='none', capsize=2,color='black')
# plt.plot(x_vals, reg_model(x_vals), color="black", linestyle="--")
plt.ylim(-5,20)
plt.xlabel("span length [ms]", fontsize=fs)
plt.ylabel(r'$Median-E$ [J] ', fontsize=fs)
#plt.title("cpu_ms = "+str(i)+" OLS model vs data")
plt.show()

# %% [markdown]
# ## Now use one span length and compare median E of sliding window with median E and CIs of previous window

# %%
# use 250 ms spans and use the 125 ms active interval
df_spans_250 = df.query("(cpu_ms == 250) & (active_interval_ms == 125)")
df_spans_250
# Out:
#                 span_id  energy_joules  cpu_ms  active_interval_ms  \
# 12500  ed7582758e6799ce       0.945241     250                 125
# 12501  ba0bfd9174204951       0.957502     250                 125
# 12502  d08f8cb440b77378       0.995960     250                 125
# 12503  84b5f3f7c9b22bdf       1.088896     250                 125
# 12504  24cbb248c604d603       0.900672     250                 125
# ...                 ...            ...     ...                 ...
# 12995  3a60efb8004d3473       1.363404     250                 125
# 12996  69312c5bbcc8630c       0.956371     250                 125
# 12997  4164910fa4fba155       1.036726     250                 125
# 12998  73c9e6727bcd009c       0.929154     250                 125
# 12999  d8b31acff75ddaee       0.834360     250                 125
#
#        median_energy_cpu_ms
# 12500              0.965244
# 12501              0.965244
# 12502              0.965244
# 12503              0.965244
# ...

# %% [markdown]
# ### what are the energies in these spans (sorted)

# %%
np.sort(df_spans_250.energy_joules.values)
# Out:
# array([0.764037, 0.77646 , 0.792894, 0.800187, 0.801678, 0.801711,
#        0.804054, 0.80491 , 0.805307, 0.805737, 0.806289, 0.807195,
#        0.810452, 0.815314, 0.819833, 0.822145, 0.823455, 0.824773,
#        0.825312, 0.826984, 0.827641, 0.829062, 0.830051, 0.83107 ,
#        0.833784, 0.83436 , 0.836647, 0.837074, 0.83907 , 0.839111,
#        0.83994 , 0.841634, 0.842633, 0.843214, 0.843411, 0.847553,
#        0.848264, 0.848517, 0.84921 , 0.850172, 0.850483, 0.852722,
#        0.854115, 0.854856, 0.855475, 0.856396, 0.857023, 0.857994,
#        0.858098, 0.860297, 0.861131, 0.861192, 0.862054, 0.862891,
#        0.864981, 0.865371, 0.866757, 0.866781, 0.867419, 0.868987,
#        0.868994, 0.869384, 0.871558, 0.871637, 0.872353, 0.873005,
#        0.873041, 0.873101, 0.873719, 0.875268, 0.875837, 0.877772,
#        0.877806, 0.879423, 0.880301, 0.880919, 0.887019, 0.887669,
#        0.887748, 0.887938, 0.889107, 0.889929, 0.890955, 0.891328,
# ...

# %%
# helper function to determine median E and CI values
def calc_median_and_ci(spans, z):
    '''
    spans: an array (list) of span energy values
    z: the z-sscore to use for the confidence intervals

    returns the mean energy, median energy, lower, and upper confidence interval values
    '''
    med = np.median(spans)
    mn = np.mean(spans)
    n = spans.size
    lower_ci_idx = int(np.floor((n - z*np.sqrt(n))/2))
    upper_ci_idx = int(np.ceil(1 + ((n + z*np.sqrt(n))/2)))
    eng_sorted = np.sort(spans)
    eng_upper_ci = eng_sorted[upper_ci_idx]
    eng_lower_ci = eng_sorted[lower_ci_idx]

    return mn, med, eng_lower_ci, eng_upper_ci

# %%
# window size parameter
w = 100

# number of spans in full dataset
N = df_spans_250.shape[0]

# Z score for 95% confidence
z = 1.96

N - w
# Out:
# 400

# %%
# gather first window stats and test function
i = 0
j = i + w

test_spans = df_spans_250[i:j]
cur_mean, cur_med, cur_low_ci, cur_up_ci = calc_median_and_ci(test_spans.energy_joules.values, z)
print(cur_mean, cur_med, cur_low_ci, cur_up_ci, test_spans.shape[0])
# Out:
# 1.00846688 0.961149 0.9541 0.990759 100

# %% [markdown]
# ### loop through energies with window of 100

# %%
for k in np.arange(0, N-w+1):
    test_spans = df_spans_250[k:k+w]
    new_mean, new_med, new_low_ci, new_up_ci = calc_median_and_ci(test_spans.energy_joules.values, z)
    if ((new_med > cur_up_ci) | (new_med < cur_low_ci)):
        print("The spans from "+str(k)+" to "+str(k+w)+" have a median E outside the CIs of previous window\n")
        print("Median E is "+str(new_med)+" versus the previous median of "+str(cur_med)+"\n")
    #elif((new_mean > cur_up_ci) | (new_mean < cur_low_ci)):
        #print("The spans from "+str(k)+" to "+str(k+w)+" have a MEAN E outside the CIs of previous window\n")
    else:
        #print("New Median E is "+str(new_med)+" versus the previous median of "+str(cur_med)+"\n")
        cur_mean = new_mean
        cur_med = new_med
        cur_up_ci = new_up_ci
        cur_low_ci = new_low_ci

# %%
print(cur_med, cur_low_ci, cur_up_ci)
# Out:
# 0.9568495 0.945502 0.993589

# %% [markdown]
# ### OK, now boost the E values of the last 50 measurements by 150%

# %%
# portion of data to boost
chunk_n = 50

df_boosted_250 = df_spans_250.copy()
df_boosted_250.tail(10)
# Out:
#                 span_id  energy_joules  cpu_ms  active_interval_ms  \
# 12990  661cca0488eaf7e2       0.977653     250                 125
# 12991  55a6783bcc6a6692       0.952388     250                 125
# 12992  c544b4333b068575       0.934121     250                 125
# 12993  5e49bd67a896b59c       0.805307     250                 125
# 12994  2147b3867bd227c0       0.957002     250                 125
# 12995  3a60efb8004d3473       1.363404     250                 125
# 12996  69312c5bbcc8630c       0.956371     250                 125
# 12997  4164910fa4fba155       1.036726     250                 125
# 12998  73c9e6727bcd009c       0.929154     250                 125
# 12999  d8b31acff75ddaee       0.834360     250                 125
#
#        median_energy_cpu_ms
# 12990              0.965244
# 12991              0.965244
# 12992              0.965244
# 12993              0.965244
# 12994              0.965244
# 12995              0.965244
# ...

# %%
df_boosted_250.index[-chunk_n]
# Out:
# np.int64(12950)

# %%
#df.at[df.index[0], 'col_0'] = 'AAA'
#df.at[df.index[-1], 'col_0'] = 'JJJ'
#df_boosted_250.at[df_boosted_250.index[-10:],'energy_joules']
df_boosted_250.loc[df_boosted_250.index >= df_boosted_250.index[-chunk_n], 
    'energy_joules'] = df_boosted_250.loc[df_boosted_250.index >= df_boosted_250.index[-chunk_n], 'energy_joules'] * 10
df_boosted_250.tail(30)
# Out:
#                 span_id  energy_joules  cpu_ms  active_interval_ms  \
# 12970  b7db3f9128bd6a51       10.26147     250                 125
# 12971  f5e5f6bf2d8a182a        9.56697     250                 125
# 12972  31b99bfc5ebcb47c       11.84050     250                 125
# 12973  cdfb16ac196e6553       11.10424     250                 125
# 12974  720b420983acd013       14.14320     250                 125
# 12975  825650c0867ccd61       10.29695     250                 125
# 12976  ffbb5483644fadd0        9.23486     250                 125
# 12977  a82f6edc5bbced85        9.06369     250                 125
# 12978  75e879537a265aee        9.25563     250                 125
# 12979  a76423f153bfbe54       10.16416     250                 125
# 12980  6a31adebf9929105        9.52270     250                 125
# 12981  22bddf90d45adb43        9.56110     250                 125
# 12982  3649f06be6dc8b4d        9.07248     250                 125
# ...

# %% [markdown]
# ### re-run the test on medians

# %%
# window size parameter
w = 100

# number of spans in full dataset
N = df_boosted_250.shape[0]

# Z score for 95% confidence
z = 1.96

N - w
# Out:
# 400

# %%
# gather first window stats and test function
i = 0
j = i + w

test_spans = df_boosted_250[i:j]
cur_mean, cur_med, cur_low_ci, cur_up_ci = calc_median_and_ci(test_spans.energy_joules.values, z)
print(cur_mean, cur_med, cur_low_ci, cur_up_ci, test_spans.shape[0])
# Out:
# 1.00846688 0.961149 0.9541 0.990759 100

# %% [markdown]
# ### loop through energies with window of 100

# %%
for k in np.arange(0, N-w+1):
    test_spans = df_boosted_250[k:k+w]
    new_mean, new_med, new_low_ci, new_up_ci = calc_median_and_ci(test_spans.energy_joules.values, z)
    if ((new_med > cur_up_ci) | (new_med < cur_low_ci)):
        print("The spans from "+str(k)+" to "+str(k+w)+" are outside the CIs of previous window\n")
        print("Median E is "+str(new_med)+" versus the previous median of "+str(cur_med)+"\n")
    else:
        #print("New Median E is "+str(new_med)+" versus the previous median of "+str(cur_med)+"\n")
        cur_mean = new_mean
        cur_med = new_med
        cur_up_ci = new_up_ci
        cur_low_ci = new_low_ci

print(cur_mean, cur_med, cur_low_ci, cur_up_ci, test_spans.shape[0], k+w)
#test_spans.tail(20)
# Out:
# 5.5691850800000005 4.7974085 1.0972309999999998 9.2744 100 500

# %%
print(cur_mean, cur_med, cur_low_ci, cur_up_ci, test_spans.shape[0], k+w)
# Out:
# 5.5691850800000005 4.7974085 1.0972309999999998 9.2744 100 500

# %%
test_spans.energy_joules.mean()
# Out:
# np.float64(1.2630730950000002)
